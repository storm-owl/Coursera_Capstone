# %% [markdown]
# <h1>Coursera Capstone</h1>
# <hr/>
# <h2>Applied Data Science Capstone - Battle of the Neighbourhoods</h2>
# In this project we will analyse neighbourhoods in Toronto to find the one that best fits a list of criteria.

# %% [markdown]
# <h3>Import Packages</h3>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h3>Sample Script</h3>

# %%
print ('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
